# %% [markdown]
# # Uber Trip Demand Forecasting
# ## Step 1: Data Loading and Basic Preprocessing
#
# In this step, we:
# - Load the Uber trip dataset
# - Inspect the data structure
# - Convert the date column to datetime
# - Sort the data chronologically
# - Set the date column as the index
#
# This prepares the dataset for exploratory data analysis and forecasting.

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv("../DATASET/Uber-Jan-Feb-FOIL.csv")

# Preview the first 5 rows
df.head()
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %% [markdown]
# ## 2️ Dataset Shape
#
# Checking the number of rows and columns helps us understand the size of the dataset.

# %%
df.shape

# %% [markdown]
# ## 3️ Column Names
#
# This step helps identify all available columns and their exact names for further processing.

# %%
df.columns

# %% [markdown]
# ## 4️ Dataset Information
#
# This step provides information about:
# - Column data types
# - Non-null values  m
# - Memory usage
#
# It is a critical step for data quality checks.

# %%
df.info()

# %% [markdown]
# ## 5️ Missing Values Check
#
# Checking for missing values is important, especially for time-series forecasting.

# %%
df.isnull().sum()

# %% [markdown]
# ## 6️ Convert Date Column to Datetime Format
#
# Time-series analysis requires the date column to be in datetime format.

# %%
# Convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
df = df.sort_values('pickup_date')

# %% [markdown]
# ## 7️ Sort Data by Date
#
# Sorting ensures the data follows a chronological order, which is essential for forecasting models.

# %%
df = df.sort_values('date')

# %% [markdown]
# ## 8️ Set Date Column as Index
#
# Setting the date column as the index allows easy resampling and rolling calculations.

# %%
df.set_index('date', inplace=True)

# %% [markdown]
# ## 9️ Statistical Summary
#
# This provides a statistical overview of the dataset such as minimum, maximum, and average trip counts.

# %%
df.describe()

# %% [markdown]
# ##  Key Observations
#
# - The dataset contains aggregated Uber trip data.
# - The data is structured as a time series.
# - The date column has been successfully converted to datetime format.
# - No critical missing values were observed.
# - The dataset is now ready for Exploratory Data Analysis (EDA).

# %%
# Reload dataset to reset state
df = pd.read_csv("../DATASET/Uber-Jan-Feb-FOIL.csv")

# Convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# Sort by date
df = df.sort_values('date')

# Set date as index
df.set_index('date', inplace=True)

# %%
# ================================
# STEP 1: DATA LOADING & PREPROCESSING
# ================================

import pandas as pd
import numpy as np

print("\n==============================")
print("1. Loading Dataset")
print("==============================")

df = pd.read_csv("../DATASET/Uber-Jan-Feb-FOIL.csv")
print("Dataset loaded successfully")

print("\n==============================")
print("2. Dataset Shape")
print("==============================")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

print("\n==============================")
print("3. Column Names")
print("==============================")
print(list(df.columns))

print("\n==============================")
print("4. Dataset Information")
print("==============================")
df.info()

print("\n==============================")
print("5. Missing Values Check")
print("==============================")
print(df.isnull().sum())

print("\n==============================")
print("6. Converting 'date' column to datetime")
print("==============================")
df['date'] = pd.to_datetime(df['date'])
print("Date column converted to datetime successfully")

print("\n==============================")
print("7. Sorting Data by Date")
print("==============================")
df = df.sort_values('date')
print("Data sorted chronologically")

print("\n==============================")
print("8. Setting Date as Index")
print("==============================")
df.set_index('date', inplace=True)
print("Date column set as index")

print("\n==============================")
print("9. Statistical Summary")
print("==============================")
display(df.describe())

print("\n==============================")
print("10. Final Dataset Preview")
print("==============================")
display(df.head())
# Out:
# ...
# 1. Loading Dataset
# ...
# Dataset loaded successfully
#
# ...
# 2. Dataset Shape
# ...
# Rows: 354, Columns: 4
#
# ...
# 3. Column Names
# ...
# ['dispatching_base_number', 'date', 'active_vehicles', 'trips']
#
# ...
# 4. Dataset Information
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dispatching_base_number  354 non-null    object
#  1   date                     354 non-null    object
#  2   active_vehicles          354 non-null    int64
#  3   trips                    354 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.2+ KB
#
# ...
# 5. Missing Values Check
# ...
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64
#
# ...
# 6. Converting 'date' column to datetime
# ...
# Date column converted to datetime successfully
#
# ...
# 7. Sorting Data by Date
# ...

# %% [markdown]
# ## Step 1 Summary: Data Loading and Preprocessing
#
# In this step, the Uber trip dataset was prepared for analysis and forecasting.
#
# ### Actions Performed
# 1. Loaded the Uber-Jan-Feb-FOIL dataset into a Pandas DataFrame.
# 2. Verified dataset dimensions and column structure.
# 3. Checked data types and confirmed the absence of critical missing values.
# 4. Converted the `date` column to datetime format.
# 5. Sorted the dataset in chronological order.
# 6. Set the `date` column as the time-series index.
# 7. Generated a statistical summary of numerical features.
#
# ### Key Columns
# - `dispatching_base_number`: Uber base identifier.
# - `active_vehicles`: Number of active vehicles on a given day.
# - `trips`: Total number of Uber trips per day.
#
# ### Outcome
# The dataset is clean, chronologically ordered, and indexed by date.
# It is now fully prepared for exploratory data analysis (EDA) and time-series forecasting.
